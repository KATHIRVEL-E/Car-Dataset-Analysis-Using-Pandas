# %%
import pandas as pd

# %%
df_ev = pd.read_csv(r"C:\Users\eshak\OneDrive\Documents\Downloads\car dataset\Cars Datasets 2025.csv", encoding='ISO-8859-1')

# %%
df.dtypes
# Out:
# Company Names                object
# Cars Names                   object
# Engines                      object
# CC/Battery Capacity          object
# HorsePower                   object
# Total Speed                  object
# Performance(0 - 100 )KM/H    object
# Cars Prices                  object
# Fuel Types                   object
# Seats                        object
# Torque                       object
# dtype: object

# %%
df_ev.shape
# Out:
# (1218, 11)

# %%
df_ev.isnull()
# Out:
# Company Names                0
# Cars Names                   0
# Engines                      0
# CC/Battery Capacity          3
# HorsePower                   0
# Total Speed                  0
# Performance(0 - 100 )KM/H    6
# Cars Prices                  0
# Fuel Types                   0
# Seats                        0
# Torque                       1
# dtype: int64

# %%
df_ev.isnull().sum()
# Out:
# Company Names                0
# Cars Names                   0
# Engines                      0
# CC/Battery Capacity          3
# HorsePower                   0
# Total Speed                  0
# Performance(0 - 100 )KM/H    6
# Cars Prices                  0
# Fuel Types                   0
# Seats                        0
# Torque                       1
# dtype: int64

# %%
df_ev.isnull().sum().sort_values(ascending=False)
# Out:
# Performance(0 - 100 )KM/H    6
# CC/Battery Capacity          3
# Torque                       1
# Company Names                0
# Cars Names                   0
# Engines                      0
# HorsePower                   0
# Total Speed                  0
# Cars Prices                  0
# Fuel Types                   0
# Seats                        0
# dtype: int64

# %%
df_ev['Torque'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1213    False
# 1214    False
# 1215    False
# 1216    False
# 1217    False
# Name: Torque, Length: 1218, dtype: bool

# %%
df_ev
# Out:
#      Company Names         Cars Names                             Engines  \
# 0          FERRARI      SF90 STRADALE                                  V8
# 1      ROLLS ROYCE            PHANTOM                                 V12
# 2             Ford                KA+                         1.2L Petrol
# 3         MERCEDES            GT 63 S                                  V8
# 4             AUDI         AUDI R8 Gt                                 V10
# ...            ...                ...                                 ...
# 1213        Toyota       Crown Signia                      2.5L Hybrid I4
# 1214        Toyota  4Runner (6th Gen)  2.4L Turbo I4 (i-FORCE MAX Hybrid)
# 1215        Toyota      Corolla Cross              2.0L Gas / 2.0L Hybrid
# 1216        Toyota             C-HR+                   1.8L / 2.0L Hybrid
# 1217        Toyota     RAV4 (6th Gen)        2.5L Hybrid / Plug-in Hybrid
#
#         CC/Battery Capacity    HorsePower Total Speed  \
# ...

# %%
df_ev['Performance(0 - 100 )KM/H'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Performance(0 - 100 )KM/H, dtype: bool

# %%
df_ev['Performance(0 - 100 )KM/H'].isnull().head(100)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Performance(0 - 100 )KM/H, Length: 100, dtype: bool

# %%
df_ev['Performance(0 - 100 )KM/H'].isnull().mean()
# Out:
# 0.0049261083743842365

# %%
df_ev.columns
# Out:
# Index(['Company Names', 'Cars Names', 'Engines', 'CC/Battery Capacity',
#        'HorsePower', 'Total Speed', 'Performance(0 - 100 )KM/H', 'Cars Prices',
#        'Fuel Types', 'Seats', 'Torque'],
#       dtype='object')

# %%
for column in df_ev.columns:
   percentage= df_ev[column].isnull().mean()
   print(column+': '+str(round(percentage*100,2)))
# Out:
# Company Names: 0.0
# Cars Names: 0.0
# Engines: 0.0
# CC/Battery Capacity: 0.25
# HorsePower: 0.0
# Total Speed: 0.0
# Performance(0 - 100 )KM/H: 0.49
# Cars Prices: 0.0
# Fuel Types: 0.0
# Seats: 0.0
# Torque: 0.08

# %%
df_ev.drop('Performance(0 - 100 )KM/H',axis=1)
# Out:
#      Company Names         Cars Names                             Engines  \
# 0          FERRARI      SF90 STRADALE                                  V8
# 1      ROLLS ROYCE            PHANTOM                                 V12
# 2             Ford                KA+                         1.2L Petrol
# 3         MERCEDES            GT 63 S                                  V8
# 4             AUDI         AUDI R8 Gt                                 V10
# ...            ...                ...                                 ...
# 1213        Toyota       Crown Signia                      2.5L Hybrid I4
# 1214        Toyota  4Runner (6th Gen)  2.4L Turbo I4 (i-FORCE MAX Hybrid)
# 1215        Toyota      Corolla Cross              2.0L Gas / 2.0L Hybrid
# 1216        Toyota             C-HR+                   1.8L / 2.0L Hybrid
# 1217        Toyota     RAV4 (6th Gen)        2.5L Hybrid / Plug-in Hybrid
#
#         CC/Battery Capacity    HorsePower Total Speed        Cars Prices  \
# ...

# %%
no_Performance(0 - 100 )KM/H=df_ev[df_ev['Performance(0 - 100 )KM/H'].isnull()].index
# Out:
# Index([241, 1096, 1107, 1108, 1126, 1147], dtype='int64')

# %%
no_Performance=df_ev[df_ev['Performance(0 - 100 )KM/H'].isnull()].index
df_ev.drop(no_Performance,axis=0).isnull().sum()
# Out:
# Company Names                0
# Cars Names                   0
# Engines                      0
# CC/Battery Capacity          2
# HorsePower                   0
# Total Speed                  0
# Performance(0 - 100 )KM/H    0
# Cars Prices                  0
# Fuel Types                   0
# Seats                        0
# Torque                       0
# dtype: int64

# %%
df_ev.head(242)
# Out:
#     Company Names                Cars Names                          Engines  \
# 0         FERRARI             SF90 STRADALE                               V8
# 1     ROLLS ROYCE                   PHANTOM                              V12
# 2            Ford                       KA+                      1.2L Petrol
# 3        MERCEDES                   GT 63 S                               V8
# 4            AUDI                AUDI R8 Gt                              V10
# ..            ...                       ...                              ...
# 237        TOYOTA            HILUX GR SPORT                2.8L,TURBO,DIESEL
# 238        TOYOTA  ALPHARD EXECUTIVE LOUNGE  2.5L,INLINE-4,HYBRID,OR 3.5L,V6
# 239        TOYOTA         FORTUNER GR SPORT                2.8L,TURBO,DIESEL
# 240        TOYOTA            INNOVA HYCROSS                      2.0L HYBRID
# 241        TOYOTA                   COASTER                      4.0L,DIESEL
#
# ...

# %%
df_ev.head(242)
# Out:
#     Company Names                Cars Names                          Engines  \
# 0         FERRARI             SF90 STRADALE                               V8
# 1     ROLLS ROYCE                   PHANTOM                              V12
# 2            Ford                       KA+                      1.2L Petrol
# 3        MERCEDES                   GT 63 S                               V8
# 4            AUDI                AUDI R8 Gt                              V10
# ..            ...                       ...                              ...
# 237        TOYOTA            HILUX GR SPORT                2.8L,TURBO,DIESEL
# 238        TOYOTA  ALPHARD EXECUTIVE LOUNGE  2.5L,INLINE-4,HYBRID,OR 3.5L,V6
# 239        TOYOTA         FORTUNER GR SPORT                2.8L,TURBO,DIESEL
# 240        TOYOTA            INNOVA HYCROSS                      2.0L HYBRID
# 241        TOYOTA                   COASTER                      4.0L,DIESEL
#
# ...

# %%
df_ev[~(df_ev['Performance(0 - 100 )KM/H'].isnull())]
# Out:
#      Company Names         Cars Names                             Engines  \
# 0          FERRARI      SF90 STRADALE                                  V8
# 1      ROLLS ROYCE            PHANTOM                                 V12
# 2             Ford                KA+                         1.2L Petrol
# 3         MERCEDES            GT 63 S                                  V8
# 4             AUDI         AUDI R8 Gt                                 V10
# ...            ...                ...                                 ...
# 1213        Toyota       Crown Signia                      2.5L Hybrid I4
# 1214        Toyota  4Runner (6th Gen)  2.4L Turbo I4 (i-FORCE MAX Hybrid)
# 1215        Toyota      Corolla Cross              2.0L Gas / 2.0L Hybrid
# 1216        Toyota             C-HR+                   1.8L / 2.0L Hybrid
# 1217        Toyota     RAV4 (6th Gen)        2.5L Hybrid / Plug-in Hybrid
#
#         CC/Battery Capacity    HorsePower Total Speed  \
# ...

# %%
df_ev.dropna(subset=['Performance(0 - 100 )KM/H']).head(146)
# Out:
#     Company Names     Cars Names         Engines CC/Battery Capacity  \
# 0         FERRARI  SF90 STRADALE              V8             3990 cc
# 1     ROLLS ROYCE        PHANTOM             V12             6749 cc
# 2            Ford            KA+     1.2L Petrol            1,200 cc
# 3        MERCEDES        GT 63 S              V8            3,982 cc
# 4            AUDI     AUDI R8 Gt             V10            5,204 cc
# ..            ...            ...             ...                 ...
# 141          AUDI       TT COUPE              I4            1,984 cc
# 142           BMW    I8 ROADSTER  ELECTRIC MOTOR            11.6 kwh
# 143           BMW           330i              I4            1,998 cc
# 144           BMW   M340i XDRIVE              I6            2,998 cc
# 145           BMW     430i COUPE              I4            1,998 cc
#
#     HorsePower Total Speed Performance(0 - 100 )KM/H      Cars Prices  \
# ...
